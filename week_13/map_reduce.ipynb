# %% [markdown]
# Map reduction
# How many times a value exist in a blocktext
#
# Steps in Comprehensive NLP system
# - Tokenization: seperateing text into smaller tokens that can be analyzed
# - Morphological: word formation
# - Syntactic Analysis: sentence structure (hard to understand the slang or the emotion)
# - Pracmatic Analysis:

# %%
! pip3 install nltk

# %%
import nltk
from nltk.tokenization import word_tokenize

# an unsupervised training model, which means 
# it can be trained on unlabeled data

text = '''
Lorem Ipsum is simply dummy text of the printing and typesetting industry. 
Lorem Ipsum has been the industry's standard dummy text ever since the 1500s, when an unknown printer took a galley of type and scrambled it to make a type specimen book. 
It has survived not only five centuries, but also the leap into electronic typesetting, remaining essentially unchanged. 
It was popularised in the 1960s with the release of Letraset sheets containing Lorem Ipsum passages, and more recently with desktop publishing software like Aldus PageMaker including versions of Lorem Ipsum.
'''

# %% [markdown]
# # Gutenberg

# %%
nltk.download('gutenberg')
nltk.corpus.gutenbergs.filieds()

# %%
aiw = nltk.corpus.gutenberg.words("carroll-alice.txt")
aiw

# %%
# stop words are common words that have
# low information value.
sw = set(nltk.corpus.stopwords.words('english'))

# ?nltk.download('stopwords')

# %%
text_sentences = nltk.corpus.gutenberg.sents('carroll-alice.txt')

# %%
# stop words are all lowercase
# so we want to make sure all our words are
# lowercase when the process them
for sentence in text_sentences:
    filtered_list = [word for word in sentence if word.lower]
    print(filtered_list)
