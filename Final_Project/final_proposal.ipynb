# %% [markdown]
# 1. I am working alone. My plan is to start working a month early to the deadline, and spend about 4-5 hours a week on this project (but the hours of commitment is quite flexible for me and is heavily depends on my project's progress).
#
# 2. I plan to use the dataset "NASA EONET Global Natural Events."
# This is the link to this dataset download page: https://www.kaggle.com/datasets/ibrahimqasimi/nasa-eonet-global-natural-events
#
# 3. My null hypothesis is that there’s no difference in the frequency of ntaural disaster events across different geographic regions or year over year. The alternative hypothesis is that there is a difference, and there are certain types of event that occured more frequent at specific areas or year.
#
# 4. I plan to use Decision-tree classifier, random forest, and Logistic regression/KNN to know which model best predicts natural event types based on location and time.
