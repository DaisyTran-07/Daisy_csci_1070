# %% [markdown]
# 1. I am working alone. My plan is to start working a month early to the deadline, and spend about 4-5 hours a week on this project (but the hours of commitment is quite flexible for me and is heavily depends on my project's progress).
#
# 2. I plan to use a messy stock market dataset on Yahoo Finance that contains daily prices, volume, and other trading data for multiple companies. This dataset is publicly available and contains missing or inconsistent values, which will give me an opportunity to practice data cleaning and preprocessing.
#
# 3. I’m starting with a hypothesis that looks at whether stock performance differs across sectors. My null hypothesis is that there’s no difference in average daily returns between companies in different sectors. The alternative hypothesis is that there is a difference. Basically, I want to see if the data supports the idea that sector really matters when it comes to returns, but it’s totally fine if the results don’t show a significant difference.
#
# 4. I plan to start with some descriptive statistics things like averages, variances, and correlations metrix to kind of understand what the data have to offer. I’ll also visualize stock trends and trading volumes to see patterns more clearly. I might also explore predictive models, like linear regression to study the link between trading volume and returns, or other models as well (I will figure this out when working on the project).
