# %%
input = [2,7,11,15]

def return_element(list, target):

    """
    take the input and check which two value in the list 
    that add together is equal to the output 
    """
    indices = []
    for index,x in enumerate(list):
        if list[x] + list[x+1] == target:
            indices.append(index, index+1)
    output = f"because "    
    return output
            
            
return_element(input, 9)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[2], line 17
#      13     output = f"because "
#      14     return output
# ---> 17 return_element(input, 9)
#
# Cell In[2], line 11, in return_element(list, target)
#       9 indices = []
#      10 for index,x in enumerate(list):
# ---> 11     if list[x] + list[x+1] == target:
#      12         indices.append(index, index+1)
#      13 output = f"because "
#
# IndexError: list index out of range

# %% [markdown]
# teach the algorithm to think, help the algorithm to learn more complex patterns in the data.
#
# Forward propagation: takes input values & propagates forward through the hidden layers -> output -> calculate errors
#
# Backward propagation: We say this is how the output should be -> go back to each model and see how the model change the output
