# %% [markdown]
# Question 1:

# %%
SELECT *
FROM payment
WHERE amount >= 9.99;

# %% [markdown]
# Question 2:

# %%
SELECT f.title, p.amount
FROM film f
JOIN inventory i ON f.film_id = i.film_id
JOIN rental r ON i.inventory_id = r.inventory_id
JOIN payment p ON r.rental_id = p.rental_id
WHERE p.amount = (
    SELECT MAX(amount)
    FROM payment);

# %% [markdown]
# Question 3:

# %%
SELECT CONCAT(s.first_name, ' ', s.last_name) AS full_name,
       s.email, a.address, ci.city, co.country
FROM staff s
JOIN address a ON s.address_id = a.address_id
JOIN city ci ON a.city_id = ci.city_id
JOIN country co ON ci.country_id = co.country_id;

# %% [markdown]
# Question 4:

# %% [markdown]
# I want to work in the investment and financial services industry, and some specific roles (intern/full time) are Equity Research Analyst, Portfolio Management, or Investment Strategist. I am open to work for any sort of company, but I prefer firms that provide annual trainings that help me growth professionally in the Finance industry and those are combine finance with data and technology. Overall, I am looking forward to working in firms that may help me becoming a successful investor by 30. I currently a freshman so my plan might change in the next few years, but overall, this is what my career's preferences.

# %% [markdown]
# Extra credit:

# %% [markdown]
# The relationship between the language and film tables is one to many. So each film must reference exactly one language through the language_id foreign key, while a language can be associated with many films. The relationship shows that the database foreign key, where many films can share the same language, but each film has only one primary language. I think this relationship make sense in real-world.
