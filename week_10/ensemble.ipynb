# %%
import pandas as pd
from sklearn import tree
from sklearn.metrics import ConfusionMatrixDisplay


diabetes_df = pd.read_csv("../week_06/diabetes.csv")
diabetes_df.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

X = diabetes_df.drop('Outcome', axis=1)
y = diabetes_df['Outcome']

X_train, X_test, y_train, y_test = train_test_split(X,y,
                                                    test_size=0.3,
                                                    random_state=43,
                                                    stratify=y)

# %%
from sklearn.ensemble import RandomForestClassifier
#random forest is an aggregated decision tree
rf = RandomForestClassifier(n_estimators=100, random_state=50)
rf = rf.fit(X_train, y_train)
rf.score(X_test, y_test)
# Out:
# 0.7748917748917749

# %%
model = model.fit(X_train, y_train)
y_pred = model.predict(X_test)
ConfusionMatrixDisplay.from_predictions(y_test, y_pred)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 model = model.fit(X_train, y_train)
#       2 y_pred = model.predict(X_test)
#       3 ConfusionMatrixDisplay.from_predictions(y_test, y_pred)
#
# NameError: name 'model' is not defined

# %%
import matplotlib.pyplot as plt
rf_tree = rf.estimators_[4]
tree.plot_tree(rf_tree)
plt.savefig("rf.")

# %%
# %pip install xgboost
# Out:
# ...
#    ---------------------------------------- 0.0/101.7 MB ? eta -:--:--
#    ---------------------------------------- 0.8/101.7 MB 6.7 MB/s eta 0:00:16
#     --------------------------------------- 1.3/101.7 MB 3.2 MB/s eta 0:00:32
#     --------------------------------------- 2.1/101.7 MB 3.4 MB/s eta 0:00:30
#     --------------------------------------- 2.4/101.7 MB 3.1 MB/s eta 0:00:32
#    - -------------------------------------- 2.9/101.7 MB 2.8 MB/s eta 0:00:35
#    - -------------------------------------- 3.4/101.7 MB 2.7 MB/s eta 0:00:37
#    - -------------------------------------- 4.2/101.7 MB 2.8 MB/s eta 0:00:35
#    - -------------------------------------- 4.7/101.7 MB 2.9 MB/s eta 0:00:34
#    -- ------------------------------------- 5.2/101.7 MB 2.9 MB/s eta 0:00:34
#    -- ------------------------------------- 6.0/101.7 MB 2.9 MB/s eta 0:00:34
#    -- ------------------------------------- 6.3/101.7 MB 2.9 MB/s eta 0:00:34
# ...

# %%
from xgboost import XGBClassifier
xgb = XGBClassifier()
xgb.fit(X_Train, y_train)

y_pred = xgb.
y_pred

# %%
ConfusionMatrixDisplay.from_estimator()

# %%
from sklearn.metrics import roc_curve, roc_auc_score
#ROC = Receiving Operating Characteristic curve
# ROC curves summarize the tradeoff between true positives and false positives. They are most appropiate for balance datasets
# Can be overly optimistic for severely imbalance classification problems
# auc = area under the curve

fpr, tpr, thresholds = roc_curve(y_test, y_pred)
auc = roc_auc_score(y_test, y_pred)
print(fpr, tpr)

# %%
# precision-recall curves summarize the tradeoff between true positive rates and positive values. These are ideal imbalanced datasets
# where one outcome is 10+x more likelu than another

from sklearn.metrics import precision_recall_score, f1_score, aucprecision, recall, thresholds = precision_recall_curve(y_)

# %%
from sklearn.svm import SVC
from sklearn.metrics import classification_report

svm_model = SVC(kernel='linear', probability=True)
svm_model.fit(X_train, y_train)
y_pred = svm_model.predict(X_test)

print("SVM Results:")
print(classification_report(y_test, y_pred))
